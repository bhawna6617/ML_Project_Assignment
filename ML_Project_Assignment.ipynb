# %% [markdown]
# # quest:-Create a folder in which you want to create the project, after that use the git init and the necessary

# %%
# To create a folder for your project and initialize a Git repository, follow these steps:

# Create a folder: Choose a location on your computer and create a new folder for your project. You can do this using the command line or your file explorer.

# Navigate to the folder: Open a terminal or command prompt and navigate to the newly created folder.

# Initialize a Git repository: Use git init to initialize an empty Git repository in the folder.

# Add files to the repository: Add the files you want to include in the repository using git add.

# Commit the files: Commit the changes to the repository using git commit.

#     Steps
# 1.Open a terminal or command prompt.

# 2.Navigate to the location where you want to create your project folder:
# cd path/to/your/directory
# 3.Create a new folder for your project:
# mkdir my_project
# cd my_project
# 4.Initialize an empty Git repository:
# git init
# 5.Create some files (optional):
# echo "# My Project" > README.md
# touch .gitignore
# 6.Add the files to the staging area:
# git add .
# 7.Commit the files:
# git commit -m "Initial commit"

# Example:-
# # Step 1: Navigate to your directory
# cd path/to/your/directory

# # Step 2: Create a new folder
# mkdir my_project
# cd my_project

# # Step 3: Initialize a Git repository
# git init

# # Step 4: Create some files (optional)
# echo "# My Project" > README.md
# touch .gitignore

# # Step 5: Add the files to the staging area
# git add .

# # Step 6: Commit the files
# git commit -m "Initial commit"

# %% [markdown]
# # quest:-Create a separate environ\ent so that you do not \ess up with your base environ\entH

# %%
# Creating a separate environment ensures that your project dependencies do not interfere with your base environment. Here’s how you can create and manage a virtual environment using venv in Python:

# Steps to Create a Virtual Environment
# 1.Navigate to your project directory:cd path/to/your/project
# 2.Create a virtual environment:python -m venv env
# 3.Activate the virtual environment:.\env\Scripts\activate,On macOS and Linux:source env/bin/activate
# 4.Install necessary packages:pip install <package_name>
# 5.Deactivate the virtual environment:deactivate
# Example
# # Step 1: Navigate to your project directory
# cd path/to/your/project

# # Step 2: Create a virtual environment
# python -m venv env

# # Step 3: Activate the virtual environment
# # On Windows
# .\env\Scripts\activate
# # On macOS and Linux
# source env/bin/activate

# # Step 4: Install necessary packages
# pip install requests

# # Step 5: Deactivate the virtual environment
# deactivate

# %% [markdown]
# # quest:-GH Create the folder structure/directories and files using the python progra\\e re=uired for a ML projectI

# %%
# To create the specified folder structure and files for an ML project using a Python script, you can use the os module. Here’s how you can create the desired structure:
#     < src
#     ├── __init__.py
#     ├── logger.py
#     ├── exception.py
#     ├── utils.py
#     ├── components
#     │   ├── __init__.py
#     │   ├── data_ingestion.py
#     │   ├── data_transformation.py
#     │   ├── model_trainer.py
#     ├── pipeline
#     │   ├── __init__.py
#     │   ├── predict_pipeline.py
#     │   ├── train_pipeline.py
# < import_data.py
# < setup.py
# < notebooks
# < requirements.txt

# import os

# # List of directories to create
# directories = [
#     "src",
#     "src/components",
#     "src/pipeline",
#     "notebooks"
# ]

# # List of files to create
# files = [
#     "src/__init__.py",
#     "src/logger.py",
#     "src/exception.py",
#     "src/utils.py",
#     "src/components/__init__.py",
#     "src/components/data_ingestion.py",
#     "src/components/data_transformation.py",
#     "src/components/model_trainer.py",
#     "src/pipeline/__init__.py",
#     "src/pipeline/predict_pipeline.py",
#     "src/pipeline/train_pipeline.py",
#     "import_data.py",
#     "setup.py",
#     "requirements.txt"
# ]

# # Create directories
# for directory in directories:
#     os.makedirs(directory, exist_ok=True)

# # Create files
# for file in files:
#     with open(file, 'w') as f:
#         pass

# print("Folder structure created successfully.")

# Running the Script
# Save the script to a file, e.g., create_structure.py, and run it using Python:
#     python create_structure.py

# %% [markdown]
# # quest:-rite the progra\ for setupIpy and the relevant dependencies in re=uire\entsItxt and generate
# eggIinfo folderH

# %%
# To set up your Python project for packaging and distribution, you'll need to create a setup.py file and a requirements.txt file. The setup.py file will include metadata and information about your project, while requirements.txt will list the dependencies needed for your project.

# Here's how you can do it:

# 1. setup.py File
# The setup.py file is the script for setting up your package. Below is an example of what it might look like:
#     from setuptools import setup, find_packages

# setup(
#     name='your_project_name',
#     version='0.1',
#     description='A description of your project',
#     author='Your Name',
#     author_email='your.email@example.com',
#     url='https://github.com/yourusername/yourproject',
#     packages=find_packages(),
#     install_requires=[
#         # List your project's dependencies here
#     ],
#     classifiers=[
#         'Programming Language :: Python :: 3',
#         'License :: OSI Approved :: MIT License',
#         'Operating System :: OS Independent',
#     ],
#     python_requires='>=3.6',
# )
# 2.Create the requirements.txt file:

# Save the following content in a file named requirements.txt:
#     numpy
# pandas
# scikit-learn
# matplotlib
# Install the necessary tools:

# Ensure you have setuptools and wheel installed:
#     pip install setuptools wheel
# Generate the egg-info directory:

# Run the following command in your project directory:
# python setup.py sdist bdist_wheel


# your_project/
# │
# ├── src/
# │   ├── __init__.py
# │   ├── logger.py
# │   ├── exception.py
# │   ├── utils.py
# │   ├── components/
# │   │   ├── __init__.py
# │   │   ├── data_ingestion.py
# │   │   ├── data_transformation.py
# │   │   ├── model_trainer.py
# │   ├── pipeline/
# │   │   ├── __init__.py
# │   │   ├── predict_pipeline.py
# │   │   ├── train_pipeline.py
# │
# ├── import_data.py
# ├── setup.py
# ├── requirements.txt
# ├── notebooks/
# └── dist/
# └── your_project_name.egg-info/

# %% [markdown]
# # quest:- Write the logging function in loggerIpy and exception function in exceptionIpy file to be used for the
# project to track the progress when the ML project is run and to raise any exception when encounteredI

# %%
# logger.py
# The logger.py file will set up logging for the project. Logging is crucial for tracking the progress of your application, as well as for debugging purposes.

# Here's an example of how you might set up a logger in logger.py
# import logging
# import os
# from datetime import datetime

# # Create logs directory if it doesn't exist
# if not os.path.exists('logs'):
#     os.makedirs('logs')

# # Configure logging
# log_filename = datetime.now().strftime('logs/logfile_%Y_%m_%d_%H_%M_%S.log')
# logging.basicConfig(
#     filename=log_filename,
#     level=logging.INFO,
#     format='%(asctime)s - %(levelname)s - %(message)s',
#     datefmt='%Y-%m-%d %H:%M:%S'
# )

# # Define a logger
# logger = logging.getLogger()

# def log_info(message):
#     logger.info(message)

# def log_error(message):
#     logger.error(message)

# def log_warning(message):
#     logger.warning(message)

    
    
# exception.py
# The exception.py file will define custom exception classes and functions to raise exceptions when encountered. This is useful for handling errors in a more controlled way and for providing more meaningful error messages.
# import logging
# from logger import log_error

# class CustomException(Exception):
#     """Base class for other exceptions"""
#     pass

# class DataIngestionException(CustomException):
#     """Raised when there is an error in data ingestion"""
#     def __init__(self, message="Error occurred in data ingestion"):
#         self.message = message
#         super().__init__(self.message)
#         log_error(self.message)

# class DataTransformationException(CustomException):
#     """Raised when there is an error in data transformation"""
#     def __init__(self, message="Error occurred in data transformation"):
#         self.message = message
#         super().__init__(self.message)
#         log_error(self.message)

# class ModelTrainingException(CustomException):
#     """Raised when there is an error in model training"""
#     def __init__(self, message="Error occurred in model training"):
#         self.message = message
#         super().__init__(self.message)
#         log_error(self.message)

# %% [markdown]
# # quest:Explorator*=Data='al*si&
